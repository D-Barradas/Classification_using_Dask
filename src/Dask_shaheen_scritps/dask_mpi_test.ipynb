# %%
import numpy as np,time

# %%
from dask.distributed import Client

# %%
import dask.array as da

# %%
import os

# %%
jobid=os.getenv('SLURM_JOBID')
client= Client(scheduler_file='scheduler_%s.json' %jobid)

print(client)
# Out:
# <Client: 'tcp://10.128.0.9:6192' processes=3 threads=3, memory=6.31 GB>

# %%
x = da.random.normal(10, 0.1, size=(20000, 20000),   # 400 million element array 
                                      chunks=(1000, 1000))   # Cut into 1000x1000 sized chunks
y = x.mean(axis=0)[::100]                            # Perform NumPy-style operations

# %%
print(x.nbytes/1e9,"GB")
start=time.time()
print(y.compute())
end=time.time()
# Out:
# 3.2 GB
# [10.00043102  9.99983785  9.9999951  10.00006379 10.00100853 10.00155396
#   9.99935925  9.99989698  9.99945366 10.00023613 10.00048237  9.99959345
#  10.00072452  9.99887678  9.9995626   9.99956411 10.00038866 10.00077411
#  10.00004615  9.99975381 10.00088002 10.00108923 10.00066982 10.00020665
#   9.99994761 10.00079501 10.00072501 10.00034404 10.00061695 10.00030357
#  10.00069856  9.99996735 10.00018626 10.00154238 10.00116358  9.99998467
#   9.99947021 10.00036547  9.99975248  9.99932602 10.00008781  9.99930015
#   9.99986872 10.00038092 10.00004671  9.99884702  9.99904514 10.00043542
#   9.99937686  9.99841669 10.00018412 10.00092613 10.00030513 10.00050851
#  10.00034809  9.99858615 10.00005705 10.00031144 10.0003591   9.99984544
#  10.00013758 10.000539    9.99962563 10.00046718 10.00001948 10.00004072
#  10.00011231 10.0003217  10.00011847  9.99930493 10.00147786 10.00043469
#   9.99937655  9.99925885  9.99869255  9.99970524  9.99993956 10.0012588
#  10.0006445  10.00014119  9.9992191   9.99940082 10.00072572 10.00049248
#   9.99998969 10.000255    9.99935342 10.00169628  9.99946019  9.99976838
#  10.00046122  9.99862908 10.00016639 10.00002323  9.99978284  9.99954063
#  10.00140954  9.99966602 10.00085446  9.99912053  9.99941604 10.00020086
#   9.99976919 10.00044589 10.00119422  9.99924169  9.99920328  9.99967423
#   9.9984274   9.99827339 10.00044441  9.99984897  9.99925385  9.99780739
#   9.99990094 10.00043908 10.00128446  9.99948465  9.9999559   9.99878756
#   9.99975274 10.0001216   9.99938201  9.99973055 10.00039241  9.99865016
#  10.00027667 10.00055446  9.99983558 10.00007387 10.00016134 10.00034345
#  10.00114526 10.00068907  9.99968752 10.00130111  9.99960974  9.99903994
#   9.99988907 10.00018495 10.00054454  9.9994363  10.00129613  9.99968991
#  10.00040446 10.00001894 10.000717    9.99947167  9.99925737 10.00016036
#   9.9992792   9.99923132  9.99922319 10.0005407  10.00041241 10.00029292
#  10.00063491 10.00029669 10.00111936  9.99959202 10.00064576  9.9999662
#   9.99884638  9.99962763 10.00015616 10.00071501 10.00040443  9.99998874
#   9.99923538  9.99903596 10.0005524  10.00119271 10.00021607 10.00011338
#   9.99925068  9.99968553  9.99974736  9.99901248  9.99857359 10.00036582
#   9.99981467  9.99954021 10.00005437  9.99904154  9.99976383 10.00043
#  10.00052031 10.00032642 10.00035684 10.00049135  9.99985765  9.9996094
#   9.99984024  9.9994244   9.99987153  9.99905892 10.00076819  9.9987822
#   9.99927606 10.00106366]

# %%
print('elapsed=',end-start)
# Out:
# elapsed= 5.091310739517212

# %%
client.close()
